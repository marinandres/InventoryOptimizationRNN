# %%
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt

# The main use of openpyxl is to open the excel file that also contain macros on it.

# %%
df = pd.read_excel("Sales.xlsm", sheet_name="Ventas")
# Out:
# d:\Users\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
dict_column = {
    "Fecha de la Factura": "date",
    "Mes": "month",
    "Ano": "year",
    "Area de Negocio": "business",
    "Tipo_Articulo": "category",
    "Descripción": "item_description",
    "Tipo de Documento": "document",
    "No.": "document_ID",
    "Cliente": "client_name",
    "Empaque": "packaging",
    "Costo Unitario USD": "unit_cost",
    "Cantidad": "sold_quantity",
    "Costo Total": "total_cost",
    "Precio de Venta": "unit_price",
    "Sub-Total": "total_sale_price",
    "Flete": "delivery_price",
    "Utilidad Gross": "gross_profit",
    "7%": "total_taxes",
    "ITBMS Retenido x Cliente": "total_tax_retention",
    "C x C USD": "current_balance",
    "Cancelado": "amount_paid",
    "Fecha de Pago": "payment_dates",
    "% Utili./Vtas": "gross_profit_percentage",
    "Comentarios": "commments",
    "R.U.C": "company_ID",
    "Direccion": "address",
    "Telefono": "phone",
    "Canal": "sales_channel" 
}

df.rename(columns=dict_column, inplace=True)

df["client_name"] = df["client_name"].astype(str) # Adding str value because some clients has numbers in their names and also dots.
df["item_description"] = df["item_description"].astype(str) # Adding to string values because is just the discription of it.

# %%
# For privacy we need no create values for each clients that help us identify the individually
client_name = df["client_name"].unique()

client_id = {}
id_counter = 1

for value in sorted(client_name):
    id_coder = value + "_ID"
    client_id[id_coder] = id_counter
    id_counter = id_counter + 1

df["client_ID"] = df["client_name"].map(lambda x: x +  "_ID").map(client_id)

# %%
rename_botella_decanter_10oz = ["Botella Decanter 10 onzas Docena",
                              "Botella Decanter 10 onzas Docena_DIC2022",
                              "Botella Decanter 10 onzas Docena_mayo2022",
                              "Botella Decanter 12 onzas Docena",
                              "Botella Decanter 12 onzas Docena_mayo2022",
                              "Frasco Decanter 10oz"
                              ]

rename_botella_woozy_5oz = ["Botella Woozy 5 onzas Docena",
                            "Botella Woozy 5 onzas Docena_DIC2022",
                            "Botella Woozy 5 onzas Docena_Impa jun21",
                            "Botella Woozy 5 onzas Docena_Impa nov21",
                            "Botella Woozy 5 onzas Docena_mayo2022"
                            ]

rename_botella_750ml = ["Botellas de 750ml vidrio",
                        "Botellas de 750ml vidrio UPIM (12xcj)",
                        "Botellas de 750ml vidrio UPIM unidad",
                        "Botellas de 750ml vidrio_Docena_EmbarqueChinaOct2020",
                        "Botellas de 750ml vidrio_ago2021",
                        "Botellas de 750ml vidrio_feb2023",
                        "botellas de 750ml vidrio_8oct2020",
                        "botellas de 750ml vidrio_dic2022",
                        "botellas de 750ml vidrio_nov2022_Lamar"
                        ]

rename_botella_375ml = ["Botella jugo 375 ml a 38mm (24xcj)",
                        "Botella jugo 375 ml a 38mm (24xcj)_19ago2020",
                        "Botella jugo 375 ml a 38mm (24xcj)_abr22",
                        "Botella jugo 375 ml a 38mm (24xcj)_dic21",
                        "Botella jugo 375 ml a 38mm (24xcj)_jun22",
                        "Botella jugo 375 ml a 38mm unidad",
                        "botella jugo 375 ml a 38mm (24xcj)"
                        ]

rename_32oz = ["Conserva 32 oz (cajas x 12)_20mar2021",
               "Conserva 32 oz (cajas x 12)_ago2021",
               "Conserva 32 oz (cajas x 12)_jun2022",
               "Conserva 32 oz (cajas x 12)_nov23",
               "Frasco de Conserva 32 oz (cajas x 12)",
               "Frasco de Conserva 32 oz (cajas x 12)_19ago2020",
               "Frasco de Conserva 32 oz (cajas x 12)_8oct2020",
               "Frasco de Conserva 32 oz unidad"
               ]

rename_69oz = ["Frasco 6.9oz 58-2020 (24xcjs)",
               "Frasco 6.9oz 58-2020 (24xcjs) unidad",
               "Frasco 6.9oz 58-2020 (24xcjs)_19ago2020",
               "Frasco 6.9oz Docena_ChinaMay21",
               "Frasco 6.9oz Docena_dic2022",
               "Frasco 6.9oz Docena_feb2023",
               "Frasco 6.9oz Docena_mayo2022",
               "Frasco 6.9oz Docena_nov2023"
               ]

rename_8oz = ["Frascos 8 oz 58-2020 (12xcjs)",
              "Frascos 8 oz 58-2020 (12xcjs) unidad",
              "Frascos 8 oz 58-2020 (12xcjs)_ago.2022",
              "Frascos 8 oz 58-2020 (12xcjs)_mar2023",
              "Frascos 8 oz 58-2020 (12xcjs)_nov.2020",
              "Frascos 8 oz 58-2020 (12xcjs)_sep.2021"
              ]

rename_16oz = ["Frascos 16oz/15oz",
               "Frascos 16oz/15oz unidad",
               "Frascos 16oz/15oz_19nov2020",
               "Frascos 16oz/15oz_nov2022",
               "Frascos 16oz/15oz_oct2023",
               "Frascos 16oz Docena_ChinaMay21"
               ]

rename_15oz = ["Frascos 1.5 onzas Hexagonal Docena",
               "Frascos 1.5 onzas Hexagonal Docena_dic2022",
               "Frascos 1.5 onzas Hexagonal Docena_jun.2023"
               ]

rename_9oz = ["Frascos 9oz-conserva",
              "Frascos 9oz-conserva feb22",
              "Frascos 9oz-conserva unidad",
              "Frascos 9oz-conserva_11feb2021",
              "Frascos 9oz-conserva_19ago2020",
              "Frascos 9oz-conserva_20mar2021",
              "Frascos 9oz-conserva_8oct2020",
              "Frascos 9oz-conserva_mayo2022",
              "Frasco 9oz Docena_ChinaMay21",
              "Frasco 9oz Docena_Dic2022"
              ]

rename_guantes = ["Guantes Cajas de 100 unidades",
                  "Guantes Cajas de 100 unidades_jun2023",
                  "Guantes Cajas de 100 unidades_nov2022"

]

rename_hexagonal_6oz = ["Frascos Hexagonal 6 oz Docena_dic2022",
                        "Frascos Hexagonal 6 oz Docena_mayo22",
                        "Frasco Hexagonal 6oz. Docena"
]

rename_garrafon = ["Tapas Garrafones EX HONG KONG",
                   "Tapas Garrafones EX HONG KONG_Nueve*_nov. 2021",
                   "Tapas Garrafones EX HONG KONG_ene. 2021",
                   "Tapas Garrafones EX HONG KONG_jun. 2021",
                   "Tapas Garrafones EX HONG KONG_jun. 2023",
                   "Tapas Garrafones EX HONG KONG_nov. 2021"
]

rename_hexagonal_4oz = ["Frasco Hexagonal 100ML o 4oz",
                        "Frasco Hexagonal 100ML o 4oz unidad",
                        "Frasco Hexagonal 100ML o 4oz_19ago2020",
                        "Frasco Hexagonal 100ML o 4oz_Dic2022",
                        "Frasco Hexagonal 100ML o 4oz_dic2022",
                        "Frasco Hexagonal 100ML o 4oz_jun.2021China",
                        "Frasco Hexagonal 100ML o 4oz_nov.2021China"
                        ]

rename_cuadrado_6oz = ["Frascos conserva 6oz cuadrada","Frascos conserva 6oz cuadrada (24un)_sep2021","Frascos conserva 6oz cuadrada unidad","Frascos conserva 6oz cuadrada_29oct2020"]

rename_tapas_28mm_blancas = ["Tapas BU32 28mm Blanco normal (4000 x cjs)_ago22",
                             "Tapas BU32 28mm Blanco normal (4000 x cjs)_mar22 Plastiglas",
                             "Tapas BU32 28mm Blanco normal (4150 x cjs)_dic2021",
                             "Tapas BU32 28mm Blanco normal (4150 x cjs)_jun2021",
                             "Tapas 28mm color BLANCO normal (4150cjs) ",
                             "Tapas PG120 28mm Blanca normal (4000 x cjs)_feb2023"
]

rename_tapas_28mm_verde = ["Tapas BU32 28mm Verde normal (4000 x cjs)_ago22",
                            "Tapas BU32 28mm Verde normal (4000 x cjs)_feb2023",
                            "Tapas BU32 28mm Verde normal (4150 x cjs)_dic2021",
                            "Tapas BU32 28mm Verde normal (4150 x cjs)_jun2021",
                            "Tapas 28mm color VERDE normal (4150cjs)",
                            "Tapas 28mm color verde (4150 x cjs) Plastiglas",
                            "Tapas 28mm color VERDE normal (4150cjs)",
                            "Tapas 28mm color VERDE normal (4150cjs)",
                            "Tapas 28mm color VERDE normal (4150cjs) "
                            ]

rename_tapas_SC_Azul = ["Tapas CDS6 28mm Azul short cut (5200 x cjs)_dic2021",
                        "Tapas CDS6 28mm Azul short cut (5200 x cjs)_jun2021",
                        "Tapas CSD6 28mm AZUL short cut normal (5500x cjs)_ago22",
                        "Tapas CSD6 28mm AZUL short cut normal (5500x cjs)_feb2023",
                        "Tapas 28mm color AZUL short cut (5200cjs)",
                        "Tapas 28mm color Azul short cut (4800 x cjs) Nuba.- impresas",
                        "Tapas 28mm color azul short cut (5200 x cjs) Plastiglas",
                        "Tapas 28mm color azul short cut (5200 x cjs)_nov21 Plastiglas",
                        "Tapas 28mm color AZUL short cut (5200cjs)",
                        "Tapas 28mm color AZUL short cut (5200cjs) "]

rename_tapas_28mm_amarilla = ["Tapas BU32 28mm Amarillo normal (4150 x cjs)_dic2021",
                              "Tapas BU32 28mm Amarillo normal (4150 x cjs)_jun2021",
                              "Tapas 28mm color AMARILLO normal (4150cjs)",
                              "Tapas PG120 28mm Amarillo normal (4000 x cjs)_ago22", 
                              "Tapas PG120 28mm Amarillo normal (4000 x cjs)_feb2023",
]

rename_tapas_38400_roja = ["Tapas 38-400 ROJAS(Plasticos Unidos)-Bolsas de 1500 tapas_mar2021",
                           "Tapas 38-400 ROJAS(Plasticos Unidos)-Bolsas de 2000 tapas",
                           "Tapas 38-400 ROJAS(Plasticos Unidos)-Bolsas de 2000 tapas_marzo22"]


rename_tapas_SC_negro = ["Tapas 28mm Color NEGRO Short cut (5600cjs)"]

rename_tapas_28mm_negro = ["Tapas 28mm Color NEGRO BU32S  (4150cjs)",
                           "Tapas 28mm Color NEGRO BU32S  (4150cjs)  ",
                           "Tapas 28mm Color NEGRO BU32S  (4150cjs) "] 

rename_tapas_sueltas = ["Tapas 28mm Color NEGRO BU32S  (4150cjs) DETAL ",
                        "Tapas 28mm Color NEGRO Short cut (5600cjs) DETAL ",
                        "Tapas 28mm Color NEGRO Short cut (5600cjs) DETAL"
                        "Tapas 28mm color AMARILLO normal (4150cjs) DETAL",
                        "Tapas 28mm color AMARILLO normal (4150cjs) DETAL ",
                        "Tapas 28mm color AMARILLO normal (4150cjs) DETAL  ",
                        "Tapas 28mm color AMARILLO normal (4150cjs) DETAL    ",
                        "Tapas 28mm color TRANS Short cut (5200cjs) DETAL",
                        "Tapas 28mm color VERDE normal (4150cjs) detal",
                        "Tapas 28mm color BLANCO normal (4150cjs) detal",
                        "Tapas 28mm color varios normal detal",
                        "Tapas 28mm Color NEGRO Short cut (5600cjs) DETAL",
                        "Tapas 28mm Color NEGRO BU32S  (4150cjs) DETAL",
                        "Tapas 28mm color AMARILLO normal (4150cjs) DETAL"]
                        
rename_tapas_28mm_azul = ["Tapas 28mm Color AZUL BU32S (4150cjs)",
                          "Tapas 28mm Color Azul-Perú (4150 x cjs) BU32S(ultimo marzo2020)"]

rename_tapas_SC_blanco = ["Tapas 28mm color BLANCO Short cut (5200cjs)",
                          "Tapas 28mm color blanco short cut (5200 x cjs) Plastiglas",
                          "Tapas CSD6 28mm Blanco short cut normal (5500x cjs)_ago22",
                          "Tapa 28mm color blanco short cut (5200 x cjs)_dic21"]


rename_tapas_38400_blanco = ["Tapas 38-400 BLANCAS(Plasticos Unidos)-Bolsas de 1500 tapas_mar2021"]

rename_tapas_28mm_rojo = ["Tapas 28mm color ROJO normal (4000cjs)_ago22",
                          "Tapas 28mm color ROJO normal (4150cjs)",
                          "Tapas BU32 28mm rojo (4000 x cjs)_feb2023"]

rename_tapas_SC_trans = ["Tapas 28mm color TRANS Short cut (5200cjs)",
                         "Tapas CSD6 28mm Trans short cut (5200 x cjs)_jun2021",
                         "Tapas 28mm color TRANS Short cut (5200cjs) "]

rename_aceite_hidraulico_AW68_5gls = ["Aciete Hidraulico AW 68(5gls)_ago23Cummings",
                                      "Aciete Hidraulico AW 68(5gls)_may22_North Start Supplier S.A",
                                      "Aceite_Hidraulico_AW68_5gls",
                                      "Aciete Hidraulico AW 68(5gls)_may22_North Start Supplier S.A.",
                                      "Aceite Hidraulico AW 68(5gls)_North Start Supplier S.A.",
                                      "Aceite Hidraulico AW 68(5gls)_jul21_North Start Supplier S.A.",
                                      "Aceite Hidraulico AW 68(5gls)_nov21_North Start Supplier S.A.",
                                      "Aceite Hidraulico AW 68(5gls)_sep22_North Start Supplier S.A.",
                                      "Aceite Hidraulico AW 68(5gls)_sep23_North Start Supplier S.A."
                                      ]

rename_aceite_15W40 = ["Aceite SAE 15W40_North Star Suppliers, S.A._55 gls_agosto21",
                       "Aceite SAE 15W40_North Star Suppliers, S.A._55 gls_dic22"]

rename_aceite_SAE50 = ["Aceite SAE 50 CF CF-2 CB (5 Galones) NEW COST",
                       "Aceite SAE 50 Motor_may2022_North Star Supplier S.A.",
                       "Aceite SAE 50 Motor_nov2021_North Star Supplier S.A.",
                       "Aceite SAE 50 Motor_oct2023_North Star Supplier S.A.",
                       "Aceite SAE 50 Motor_sep2022_North Star Supplier S.A."]

rename_aceite_80W90 = ["Aceite SAE 80W90_North Star Suppliers, S.A.",
                       "Aceite SAE 80W90_North Star Suppliers, S.A._feb22",
                       "Aceite SAE 80W90_North Star Suppliers, S.A._jun22",
                       "Aceite SAE 80W90_North Star Suppliers, S.A._oct22",
                       "Aceite SAE 80W90_North Star Suppliers, S.A._sep21",
                       "Aceite Gear HD SAE 80W-90 API GL-5 CB NEW Cost AGOSTO"]

rename_aceite_85W140 = ["Aceite SAE 85W140 55 gl_North Star Suppliers, S.A._dic21",
                        "Aceite SAE 85W140 55 gl_North Star Suppliers, S.A._sep22",
                        "Aceite SAE 85W140_55 gls_North Star Suppliers, S.A.",
                        "Aceite SAE 85W140_55 gls_North Star Suppliers, S.A._jul21",
                        "Aceite SAE 85W140_North Star Suppliers, S.A.",
                        "Aceite SAE 85W140_ene22_North Star Suppliers, S.A.",
                        "Aceite SAE 85W140_jul21_North Star Suppliers, S.A.",
                        "Aceite SAE 85W140_jun22_North Star Suppliers, S.A.",
                        "Aceite SAE 85W140_oct22_North Star Suppliers, S.A.",
                        "Aceite SAE 85W140_oct22_North Star Suppliers, S.A._Indigo",
                        "Aceite SAE 85W140_oct23_North Star Suppliers, S.A."]


rename_aceite_85W140_5gl = ["Aceite SUPER GEAR 85W-140 GL-5 CB 19L NEW COST"]


rename_aceite_SAE50_5gl = ["Aceite Sae 50 Motor (5 gls)_oct21_North Star Supplier S.A.",
                           "Aceite Sae 50 Motor_North Star Supplier S.A."]

rename_aceite_10W30_4to = ["Aceite Sintetico 10W30 Nanotec cuarto NEW COST AGOSTO",
                           "Aceite Sintetico Nanotec 10W30 cuarto_febrero23"]

rename_aceite_transmision = ["Aceite Transmision 50TO 4 NEW COST AGOSTO"]


rename_aceite_hidraulico_AW68_55gls = ["Aciete Hidraulico AW 68(55gls)_North Start Supplier S.A.",
                                       "Aciete Hidraulico AW 68(55gls)_North Start Supplier S.A._JUNIO2021",
                                       "Aciete Hidraulico AW 68(55gls)_North Start Supplier S.A._dic21",
                                       "Aciete Hidraulico AW 68(55gls)_North Start Supplier S.A._mayo22",
                                       "Aciete Hidraulico AW 68(55gls)_ago23Cummings","Aceite Hidraulico AW 68(55gls)_North Start Supplier S.A._jul23",
                                       "Aceite Hidraulico AW 68(55gls)_North Start Supplier S.A._sep22"]

rename_aceite_25W60 = ["ALTO KM SAE 25W60 (5Gls)_Global Oil",
                       "ALTO KM SAE 25W60 API CF VERDE (5Gls) Oct2021",
                       "ALTO KM SAE 25W60 API CF VERDE NEW COST",
                       "ALTO KM SAE 25W60 API CF VERDE NEW COST galon"]

rename_aceite_tractorfluid_5gl = ["Ac Tractor Fluid (5gls) IMPA_oct2021",
                              "Ac Tractor Fluid (5gls) New MArzo2019"]

rename_aceite_10W30_4to = ["Aceite  10W30 cuarto API SL CJ NEW COST AGOSTO",
                           "Aceite  10W30 cuarto API SL CJ_febrero23","Aceite Sintetico Nanotec 10W30 cuarto_febrero23"]

rename_aceite_10W = ["Aceite 10W Hidraulico ( 5gls)", "Aciete ISO 32 (5gls)_oct23_North Start Supplier S.A."]

rename_aceite_15W40_55gl = ["Aceite 15W/40 API CI-4/SL T (55 Gls) NEW COST",
                            "Aceite 15W/40 API CI-4/SL T (55 Gls) Oct2021",
                            "Aceite 15W/40 API CI-4/SL T (55 Gls)_febrero23 ",
                            "Aceite 15W/40 API CI-4/SL T (55 Gls)_febrero23"] 

rename_aceite_15W40_5gl = ["Aceite 15W/40 CI-4 8197 CB (5 Gls) NEW COST",
                           "Aceite 15W/40 CI-4 8197 CB (5 Gls) Oct2021",
                           "Aceite 15W/40 CI-4 8197 CB (5 Gls) Plus_Cummings",
                           "Aceite 15W/40 CI-4 8197 CB (5 Gls)_febrero23 ",
                           "Aceite 15W/40 CI-4 plus (5 Gls) North Star",
                           "Aceite 15W/40 CI-4 8197 CB (5 Gls)_febrero23"]

rename_aceite_15W40_4to = ["Aceite 15W/40 CI-4 8197 CB (CUARTO)_febrero23",
                           "Aceite 15W/40 CI-4 8197 CB (CUARTO5 ) NEW COST AGOSTO",
                           "Aceite 15W/40 CI-4 8197 CB (CUARTO5 ) Oct2021",
                           "Aceite Diesel 15W40 CI-4 Caja 4 de 3 (1Gl) NEW COST",
                           "Aceite Diesel 15W40 CI-4 Caja 4 de 3 (1Gl) Oct2021",
                           "Aceite Diesel 15W40 CI-4 Caja 4 de 3 (1Gl)_febrero2023",
                           "Aceite 15W/40 CI-4 8197 CB (CUARTO)_febrero23 ",
                           "Aceite Diesel 15W40 CI-4 Caja 4 de 3 (1Gl)_febrero2023 "]

rename_aceite_20W50_1gl = ["Aceite 20W50 Galon ENERO2020",
                       "Aceite Motor 20W50 Gonher (galon)_Impa"]



rename_aceite_20W50_4to = ["Aceite Motor 20W50 Cuartos",
                           "Aceite Motor 20W50 Gonher (cuarto)_Impa",
                           "Aceite Motor 20W50 Gonher (cuarto)_Impa jul22"
                           ]
rename_aceite_nanotek_15W40 = ["Aceite Nanotek SAE 15W40 API CI-4 Plus (5 Gls) Oct2021",
                               "Aceite Nanotek SAE 15W40 API CI-4 Plus (5 Gls)NEW COST"]

rename_coolan = ["Coolan (1 gl) ANT SERV PES PREMEZ 50/50 CJ 4 NEW COST",
                 "Coolan Balde (5 gls) ANT SERV PES PREMEZ 50/50 CJ 4",
                 "Coolan Balde (5 gls) ANT SERV PES PREMEZ 50/50 CJ 4 Oct2021",
                 "Coolan Balde ANT SERV PES PREMEZ CB_febrero23",
                 "Puma Coolant 50/50 1x3x1 Gl",
                 "Puma HD Coolant 50/50 1x5 gl",
                 "Puma HD Coolant 50/50 1x5 gl sep2021",
                 "Puma HD Coolant 50/50 1x55 gl"]

rename_grasas = ["Grasa Litio Moly EP-2 CB 16k (5 Gls) New Cost AGOSTO",
                 "Grasa Litio Moly EP-2 CB 16k (5 Gls) Oct2021",
                 "Grasa Moly EP-2 Caja 10 de 400 Gr. (Tubos) Oct2021",
                 "Grasa Moly EP-2 Caja 10 de 400 Gr. (Tubos)NEW COST",
                 "Grasas Chasis Tipo F Roja CB 16K (5 Gls)","Grasas Chasis Tipo F Roja CB 16K (5 Gls)_febrero23"]

rename_sello_seguridad = ["Sellos de Seguridad Millar Garrafon"

]

rename_mascarilla = ["Mascarillas Quirurgicas",
                     "Mascarillas Quirurgicas Caja 50",
                     "Mascarillas con Tiras"
]

rename_plastico = ["Envase de 12 onzas",
                   "Envase de 16 onzas ",
                   "Envase de 12 onzas ",
                   "Envase de 8 onzas ",
                   "Envase de 8 onzas",
                   "Envases 1 Litro",
                   "Envases 24 oz Salsas",
                   "Envases Pachita 8 oz. Gel",
                   "Envases Plasticos Galon con tapa y asa",
                   "Envases de 1 lts con relieve",
                   "Envases de 1.5 lts",
                   "Gotero 24 mm grande",
                   "Gotero de Botella 5 onzas",
                   "Botella de 750 ml Pets",
                   "Botella fluted 12 onzas"]

rename_gorro = ["Gorro tipo Gusano Azul",
                "Gorro tipo Gusano Azul -ex China 1x100",
                "Gorro tipo Gusano Azul_Panedi ene2021",
                "Gorro tipo Gusano Blanco-ex China 1x100"]

rename_alquiler = ["Alquiler Boom Man Lift",
                   "Alquiler de Retroexcavadora 416E"]

for index, value in df["item_description"].items():
    if value in rename_botella_woozy_5oz:
        df.at[index, "item_description"] = "Botella_Woozy_5oz"
    elif value in rename_botella_750ml:
        df.at[index, "item_description"] = "Botella_750ml"
    elif value in rename_botella_decanter_10oz:
        df.at[index, "item_description"] = "Botella_Decanter_10oz"
    elif value in rename_botella_375ml:
        df.at[index, "item_description"] = "Botella_375ml"
    elif value in rename_32oz:
        df.at[index, "item_description"] = "Frasco_32oz"
    elif value in rename_69oz:
        df.at[index, "item_description"] = "Frasco_6.9oz"
    elif value in rename_8oz:
        df.at[index, "item_description"] = "Frasco_8oz"
    elif value in rename_16oz:
        df.at[index, "item_description"] = "Frasco_16oz"
    elif value in rename_15oz:
        df.at[index, "item_description"] = "Frasco_1.5oz"
    elif value in rename_9oz:
        df.at[index, "item_description"] = "Frasco_9oz"
    elif value in rename_guantes:
        df.at[index, "item_description"] = "Guantes"
    elif value in rename_hexagonal_6oz:
        df.at[index, "item_description"] = "Frasco_Hexagonal_6oz"
    elif value in rename_garrafon:
        df.at[index, "item_description"] = "Tapas_Garrafon"
    elif value in rename_hexagonal_4oz:
        df.at[index, "item_description"] = "Frasco_Hexagonal_4oz"
    elif value in rename_tapas_28mm_blancas:
        df.at[index, "item_description"] = "Tapas_28mm_Blancas"
    elif value in rename_aceite_hidraulico_AW68_5gls:
        df.at[index, "item_description"] = "Aceite_Hidraulico_AW68_5gls"
    elif value in rename_sello_seguridad:
        df.at[index, "item_description"] = "Sello_Seguridad"
    elif value in rename_tapas_38400_roja:
        df.at[index, "item_description"] = "Tapa_38_400_roja"
    elif value in rename_tapas_28mm_verde:
        df.at[index, "item_description"] = "Tapa_BU32_28mm_Verde"
    elif value in rename_tapas_28mm_amarilla:
        df.at[index, "item_description"] = "Tapa_BU32_28mm_Amarilla"
    elif value in rename_tapas_SC_Azul:
        df.at[index, "item_description"] = "Tapa_SC_Azul"
    elif value in rename_tapas_SC_negro:
        df.at[index, "item_description"] = "Tapa_SC_Negro"
    elif value in rename_tapas_28mm_negro:
        df.at[index, "item_description"] = "Tapa_BU32_28mm_Negro"
    elif value in rename_tapas_sueltas:
        df.at[index, "item_description"] = "Tapa_Individual"
    elif value in rename_tapas_28mm_azul:
        df.at[index, "item_description"] = "Tapa_BU32_28mm_Azul"
    elif value in rename_tapas_SC_blanco:
        df.at[index, "item_description"] = "Tapa_SC_Blanco"
    elif value in rename_tapas_38400_blanco:
        df.at[index, "item_description"] = "Tapa_38_400_Blanco"
    elif value in rename_tapas_28mm_rojo:
        df.at[index, "item_description"] = "Tapa_BU32_28mm_Rojo"
    elif value in rename_tapas_SC_trans:
        df.at[index, "item_description"] = "Tapa_SC_Trans"
    elif value in rename_cuadrado_6oz:
        df.at[index, "item_description"] = "Frasco_Cuadrado_6oz"
    elif value in rename_mascarilla:
        df.at[index, "item_description"] = "Mascarilla"
    elif value in rename_aceite_15W40:
        df.at[index, "item_description"] = "Aceite_15W40"
    elif value in rename_aceite_SAE50:
        df.at[index, "item_description"] = "Aceite_SAE50"
    elif value in rename_aceite_80W90:
        df.at[index, "item_description"] = "Aceite_80W90"
    elif value in rename_aceite_85W140:
        df.at[index, "item_description"] = "Aceite_85W140"
    elif value in rename_aceite_85W140_5gl:
        df.at[index, "item_description"] = "Aceite_85W140_5gl"
    elif value in rename_aceite_SAE50_5gl:
        df.at[index, "item_description"] = "Aceite_SAE50_5gl"
    elif value in rename_aceite_10W30_4to:
        df.at[index, "item_description"] = "Aceite_10W30_4to"
    elif value in rename_aceite_transmision:
        df.at[index, "item_description"] = "Aceite_Transmision"
    elif value in rename_aceite_hidraulico_AW68_55gls:
        df.at[index, "item_description"] = "Aceite_Hidraulico_AW68_55gl"
    elif value in rename_plastico:
        df.at[index, "item_description"] = "Envases_Plasticos"
    elif value in rename_aceite_25W60:
        df.at[index, "item_description"] = "Aceite_25W60"
    elif value in rename_aceite_tractorfluid_5gl:
        df.at[index, "item_description"] = "Aceite_TractorFluid_5gl"
    elif value in rename_aceite_10W30_4to:
        df.at[index, "item_description"] = "Aceite_10W30_4to"
    elif value in rename_aceite_10W:
        df.at[index, "item_description"] = "Aceite_10W"
    elif value in rename_aceite_15W40_55gl:
        df.at[index, "item_description"] = "Aceite_15W40_55gl"
    elif value in rename_aceite_15W40_5gl:
        df.at[index, "item_description"] = "Aceite_15W40_5gl"
    elif value in rename_aceite_15W40_4to:
        df.at[index, "item_description"] = "Aceite_15W40_4to"
    elif value in rename_aceite_20W50_1gl:
        df.at[index, "item_description"] = "Aceite_20W50_1gl"
    elif value in rename_aceite_20W50_4to:
        df.at[index, "item_description"] = "aceite_20W50_4to"
    elif value in rename_aceite_nanotek_15W40:
        df.at[index, "item_description"] = "aceite_nanotek_15W40"
    elif value in rename_gorro:
        df.at[index, "item_description"] = "Gorro"
    elif value in rename_alquiler:
        df.at[index, "item_description"] = "Alquiler_Equipos"
    elif value in rename_coolan:
        df.at[index, "item_description"] = "Coolan"
    elif value in rename_grasas:
        df.at[index, "item_description"] = "Grasas"

# %%
item_name = df["item_description"].unique()

item_id = {}
id_counter = 1

for value in sorted(item_name):
    id_coder = value + "_ID"
    item_id[id_coder] = id_counter
    id_counter = id_counter + 1

df["item_ID"] = df["item_description"].map(lambda x: x +  "_ID").map(item_id)

# %%
df['date'] = pd.to_datetime(df['date'])

df['year_extracted'] = df['date'].dt.year
df['month_extracted'] = df['date'].dt.month
df['day_extracted'] = df['date'].dt.day

# %%
# Starting with value replacement
df["business"] = np.where(df["business"].isna(), 'Industrial', df["business"]) # Decision taken base on the clients and items that were selled.
df["category"] = np.where(df["category"] == 'Retroexcavadora 416E', 'Alquiler', df["category"]) # Alquiler are the best category for this products
df["category"] = np.where(df["category"] == 'Boom Man Lift', 'Alquiler', df["category"]) # Alquiler are the best category for this products
df["document"] = np.where(df["document"].isna(), 'Factura', df["document"]) # This register were also sold
df["document_ID"] = np.where(df["document_ID"].isna(), 9999, df["document_ID"]) # This register were also sold
df["packaging"] = np.where(df["packaging"] == '5 gls', '5gls', df["packaging"]) # Wrong registration

# Try to validate that al number should be positive.
df[['unit_cost','sold_quantity',
       'total_cost', 'unit_price', 'total_sale_price', 'delivery_price','gross_profit', 'total_taxes','amount_paid','gross_profit_percentage','current_balance']] = df[['unit_cost','sold_quantity',
       'total_cost', 'unit_price', 'total_sale_price', 'delivery_price','gross_profit', 'total_taxes','amount_paid','gross_profit_percentage','current_balance']].abs()

# %%
dropping = ['company_ID', 'commments', 'phone', 'sales_channel', 'month', 'year']
index_category = df[(df["category"].isna())].index
index_varios = df[(df["category"] == 'Varios')].index

df = df.drop(columns=dropping)
df.drop(index_category, inplace=True)
df.drop(index_varios, inplace=True)

# %%
df.to_csv('stats.csv', index = False)

# %%
name = df["category"].unique()
name
# Out:
# array(['Tapas', 'Lubricantes', 'Gorro/Mascarilla', 'Frascos', 'Anulación',
#        'Alquiler', 'Pets', 'Despacho'], dtype=object)
